# %% [markdown]
# ## Exploring Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("mcdonalds.csv")

# %%
df.columns
# Out:
# Index(['yummy', 'convenient', 'spicy', 'fattening', 'greasy', 'fast', 'cheap',
#        'tasty', 'expensive', 'healthy', 'disgusting', 'Like', 'Age',
#        'VisitFrequency', 'Gender'],
#       dtype='object')

# %%
df.keys()
# Out:
# Index(['yummy', 'convenient', 'spicy', 'fattening', 'greasy', 'fast', 'cheap',
#        'tasty', 'expensive', 'healthy', 'disgusting', 'Like', 'Age',
#        'VisitFrequency', 'Gender'],
#       dtype='object')

# %%
df.shape
# Out:
# (1453, 15)

# %%
df.head(5)
# Out:
#   yummy convenient spicy fattening greasy fast cheap tasty expensive healthy  \
# 0    No        Yes    No       Yes     No  Yes   Yes    No       Yes      No
# 1   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes       Yes      No
# 2    No        Yes   Yes       Yes    Yes  Yes    No   Yes       Yes     Yes
# 3   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes        No      No
# 4    No        Yes    No       Yes    Yes  Yes   Yes    No        No     Yes
#
#   disgusting Like  Age      VisitFrequency  Gender
# 0         No   -3   61  Every three months  Female
# 1         No   +2   51  Every three months  Female
# 2         No   +1   62  Every three months  Female
# 3        Yes   +4   69         Once a week  Female
# 4         No   +2   49        Once a month    Male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   yummy           1453 non-null   object
#  1   convenient      1453 non-null   object
#  2   spicy           1453 non-null   object
#  3   fattening       1453 non-null   object
#  4   greasy          1453 non-null   object
#  5   fast            1453 non-null   object
#  6   cheap           1453 non-null   object
#  7   tasty           1453 non-null   object
#  8   expensive       1453 non-null   object
#  9   healthy         1453 non-null   object
#  10  disgusting      1453 non-null   object
#  11  Like            1453 non-null   object
#  12  Age             1453 non-null   int64
#  13  VisitFrequency  1453 non-null   object
#  14  Gender          1453 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 170.4+ KB

# %%
df.head(5)
# Out:
#   yummy convenient spicy fattening greasy fast cheap tasty expensive healthy  \
# 0    No        Yes    No       Yes     No  Yes   Yes    No       Yes      No
# 1   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes       Yes      No
# 2    No        Yes   Yes       Yes    Yes  Yes    No   Yes       Yes     Yes
# 3   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes        No      No
# 4    No        Yes    No       Yes    Yes  Yes   Yes    No        No     Yes
#
#   disgusting Like  Age      VisitFrequency  Gender
# 0         No   -3   61  Every three months  Female
# 1         No   +2   51  Every three months  Female
# 2         No   +1   62  Every three months  Female
# 3        Yes   +4   69         Once a week  Female
# 4         No   +2   49        Once a month    Male

# %%
df.isnull().sum()
# Out:
# yummy             0
# convenient        0
# spicy             0
# fattening         0
# greasy            0
# fast              0
# cheap             0
# tasty             0
# expensive         0
# healthy           0
# disgusting        0
# Like              0
# Age               0
# VisitFrequency    0
# Gender            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 22

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df["yummy"]=label.fit_transform(df["yummy"])

# %%
df.head()
# Out:
#    yummy convenient spicy fattening greasy fast cheap tasty expensive healthy  \
# 0      0        Yes    No       Yes     No  Yes   Yes    No       Yes      No
# 1      1        Yes    No       Yes    Yes  Yes   Yes   Yes       Yes      No
# 2      0        Yes   Yes       Yes    Yes  Yes    No   Yes       Yes     Yes
# 3      1        Yes    No       Yes    Yes  Yes   Yes   Yes        No      No
# 4      0        Yes    No       Yes    Yes  Yes   Yes    No        No     Yes
#
#   disgusting Like  Age      VisitFrequency  Gender
# 0         No   -3   61  Every three months  Female
# 1         No   +2   51  Every three months  Female
# 2         No   +1   62  Every three months  Female
# 3        Yes   +4   69         Once a week  Female
# 4         No   +2   49        Once a month    Male

# %%
df["convenient"]=label.fit_transform(df["convenient"])

# %%
df.head()
# Out:
#    yummy  convenient spicy fattening greasy fast cheap tasty expensive  \
# 0      0           1    No       Yes     No  Yes   Yes    No       Yes
# 1      1           1    No       Yes    Yes  Yes   Yes   Yes       Yes
# 2      0           1   Yes       Yes    Yes  Yes    No   Yes       Yes
# 3      1           1    No       Yes    Yes  Yes   Yes   Yes        No
# 4      0           1    No       Yes    Yes  Yes   Yes    No        No
#
#   healthy disgusting Like  Age      VisitFrequency  Gender
# 0      No         No   -3   61  Every three months  Female
# 1      No         No   +2   51  Every three months  Female
# 2     Yes         No   +1   62  Every three months  Female
# 3      No        Yes   +4   69         Once a week  Female
# 4     Yes         No   +2   49        Once a month    Male

# %%
df["spicy"]=label.fit_transform(df["spicy"])

# %%
df["fattening"]=label.fit_transform(df["fattening"])

# %%
df["greasy"]=label.fit_transform(df["greasy"])

# %%
df["fast"]=label.fit_transform(df["fast"])

# %%
df["cheap"]=label.fit_transform(df["cheap"])

# %%
df["expensive"]=label.fit_transform(df["expensive"])

# %%
df["healthy"]=label.fit_transform(df["healthy"])

# %%
df["disgusting"]=label.fit_transform(df["disgusting"])

# %%
df.head(5)
# Out:
#    yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  expensive  \
# 0      0           1      0          1       0     1      1      0          1
# 1      1           1      0          1       1     1      1      1          1
# 2      0           1      1          1       1     1      0      1          1
# 3      1           1      0          1       1     1      1      1          0
# 4      0           1      0          1       1     1      1      0          0
#
#    healthy  disgusting Like  Age      VisitFrequency  Gender
# 0        0           0   -3   61  Every three months  Female
# 1        0           0   +2   51  Every three months  Female
# 2        1           0   +1   62  Every three months  Female
# 3        0           1   +4   69         Once a week  Female
# 4        1           0   +2   49        Once a month    Male

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   yummy           1453 non-null   int32
#  1   convenient      1453 non-null   int32
#  2   spicy           1453 non-null   int32
#  3   fattening       1453 non-null   int32
#  4   greasy          1453 non-null   int32
#  5   fast            1453 non-null   int32
#  6   cheap           1453 non-null   int32
#  7   tasty           1453 non-null   int32
#  8   expensive       1453 non-null   int32
#  9   healthy         1453 non-null   int32
#  10  disgusting      1453 non-null   int32
#  11  Like            1453 non-null   object
#  12  Age             1453 non-null   int64
#  13  VisitFrequency  1453 non-null   object
#  14  Gender          1453 non-null   object
# dtypes: int32(11), int64(1), object(3)
# memory usage: 108.0+ KB

# %%
X=df.iloc[:,:-4]

# %%
X.head()
# Out:
#    yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  expensive  \
# 0      0           1      0          1       0     1      1      0          1
# 1      1           1      0          1       1     1      1      1          1
# 2      0           1      1          1       1     1      0      1          1
# 3      1           1      0          1       1     1      1      1          0
# 4      0           1      0          1       1     1      1      0          0
#
#    healthy  disgusting
# 0        0           0
# 1        0           0
# 2        1           0
# 3        0           1
# 4        1           0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_value=scaler.fit_transform(X)

# %%
X_value
# Out:
# array([[-1.11147857,  0.31873518, -0.32134871, ...,  1.339489  ,
#         -0.49827882, -0.56648839],
#        [ 0.89970246,  0.31873518, -0.32134871, ...,  1.339489  ,
#         -0.49827882, -0.56648839],
#        [-1.11147857,  0.31873518,  3.11188424, ...,  1.339489  ,
#          2.00690848, -0.56648839],
#        ...,
#        [ 0.89970246,  0.31873518, -0.32134871, ...,  1.339489  ,
#         -0.49827882, -0.56648839],
#        [ 0.89970246,  0.31873518, -0.32134871, ..., -0.74655335,
#          2.00690848, -0.56648839],
#        [-1.11147857,  0.31873518, -0.32134871, ...,  1.339489  ,
#         -0.49827882,  1.76526126]])

# %%
df_copy=pd.DataFrame(X_value,columns=features)

# %%
features={"PC1":0,"PC2":1,"PC3":2,"PC4":3,"PC5":4,"PC6":5,"PC7":6,"PC8":7,"PC9":8,"PC10":9,"PC11":10}

# %%
df_copy
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -1.111479  0.318735 -0.321349  0.391375 -1.054476  0.332951  0.818605
# 1     0.899702  0.318735 -0.321349  0.391375  0.948339  0.332951  0.818605
# 2    -1.111479  0.318735  3.111884  0.391375  0.948339  0.332951 -1.221590
# 3     0.899702  0.318735 -0.321349  0.391375  0.948339  0.332951  0.818605
# 4    -1.111479  0.318735 -0.321349  0.391375  0.948339  0.332951  0.818605
# ...        ...       ...       ...       ...       ...       ...       ...
# 1448 -1.111479  0.318735 -0.321349  0.391375  0.948339 -3.003446 -1.221590
# 1449  0.899702  0.318735 -0.321349  0.391375 -1.054476 -3.003446  0.818605
# 1450  0.899702  0.318735 -0.321349  0.391375 -1.054476  0.332951 -1.221590
# 1451  0.899702  0.318735 -0.321349 -2.555092 -1.054476  0.332951  0.818605
# 1452 -1.111479  0.318735 -0.321349  0.391375  0.948339 -3.003446 -1.221590
#
#            PC8       PC9      PC10      PC11
# ...

# %%
df_copy.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -1.111479  0.318735 -0.321349  0.391375 -1.054476  0.332951  0.818605
# 1  0.899702  0.318735 -0.321349  0.391375  0.948339  0.332951  0.818605
# 2 -1.111479  0.318735  3.111884  0.391375  0.948339  0.332951 -1.221590
# 3  0.899702  0.318735 -0.321349  0.391375  0.948339  0.332951  0.818605
# 4 -1.111479  0.318735 -0.321349  0.391375  0.948339  0.332951  0.818605
#
#         PC8       PC9      PC10      PC11
# 0 -1.345528  1.339489 -0.498279 -0.566488
# 1  0.743203  1.339489 -0.498279 -0.566488
# 2  0.743203  1.339489  2.006908 -0.566488
# 3  0.743203 -0.746553 -0.498279  1.765261
# 4 -1.345528 -0.746553  2.006908 -0.566488

# %%
df_copy.describe()
# Out:
#                 PC1           PC2           PC3           PC4           PC5  \
# count  1.453000e+03  1.453000e+03  1.453000e+03  1.453000e+03  1.453000e+03
# mean  -8.068792e-17 -1.130853e-16  3.667633e-17 -1.711562e-17  5.623704e-17
# std    1.000344e+00  1.000344e+00  1.000344e+00  1.000344e+00  1.000344e+00
# min   -1.111479e+00 -3.137401e+00 -3.213487e-01 -2.555092e+00 -1.054476e+00
# 25%   -1.111479e+00  3.187352e-01 -3.213487e-01  3.913753e-01 -1.054476e+00
# 50%    8.997025e-01  3.187352e-01 -3.213487e-01  3.913753e-01  9.483388e-01
# 75%    8.997025e-01  3.187352e-01 -3.213487e-01  3.913753e-01  9.483388e-01
# max    8.997025e-01  3.187352e-01  3.111884e+00  3.913753e-01  9.483388e-01
#
#                 PC6           PC7           PC8           PC9          PC10  \
# count  1.453000e+03  1.453000e+03  1.453000e+03  1.453000e+03  1.453000e+03
# mean   2.335060e-16  3.545378e-17  3.667633e-17  3.178615e-17  7.090757e-17
# ...

# %%
df_copy.corr()
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# PC1   1.000000  0.253807  0.008742 -0.087027 -0.151853  0.106836  0.105036
# PC2   0.253807  1.000000  0.028928  0.036451 -0.106948  0.243062  0.151574
# PC3   0.008742  0.028928  1.000000 -0.041322  0.053932  0.020276  0.017203
# PC4  -0.087027  0.036451 -0.041322  1.000000  0.319283  0.045600 -0.026640
# PC5  -0.151853 -0.106948  0.053932  0.319283  1.000000 -0.058212 -0.073264
# PC6   0.106836  0.243062  0.020276  0.045600 -0.058212  1.000000  0.252133
# PC7   0.105036  0.151574  0.017203 -0.026640 -0.073264  0.252133  1.000000
# PC8   0.687280  0.289755  0.061154 -0.087561 -0.163536  0.145836  0.139485
# PC9  -0.061727 -0.163961  0.045979  0.089134  0.147283 -0.201694 -0.721593
# PC10  0.247183  0.099230  0.106252 -0.338401 -0.211186  0.033596  0.130003
# PC11 -0.419852 -0.340797  0.032834  0.146054  0.321879 -0.137993 -0.125602
#
#            PC8       PC9      PC10      PC11
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_copy.describe(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=10)

# %%
pcaform=pca.fit_transform(df_copy)

# %%
pcaform
# Out:
# array([[ 0.7043341 , -0.43701594,  0.26869753, ..., -0.68711581,
#          0.36759835,  0.32116088],
#        [-0.46782033,  0.36427698, -1.59683477, ...,  0.44600277,
#          0.22185463,  0.19126755],
#        [ 0.19198578,  1.71294939, -0.3394127 , ..., -0.66857633,
#          1.37722643, -1.25929967],
#        ...,
#        [-0.41427514,  1.8104382 , -1.07194798, ..., -0.39798355,
#         -0.3448475 ,  0.09855804],
#        [-2.80362953,  0.56275909,  2.27888724, ...,  0.60412308,
#         -0.21143409,  0.08312666],
#        [ 3.49910468,  1.06999906,  0.14897107, ...,  0.04948718,
#         -0.96426896,  0.07057896]])

# %%
pcaform=pd.DataFrame(pcaform)

# %%
pcaform
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.704334 -0.437016  0.268698 -0.872074 -1.521184  0.470160 -0.030969
# 1    -0.467820  0.364277 -1.596835 -0.004835  0.462385 -0.449321  0.087351
# 2     0.191986  1.712949 -0.339413  3.368168 -1.266802  0.148058 -0.606634
# 3    -0.116991 -1.155122 -1.003913  0.469589  1.141750 -0.857182  0.015843
# 4    -0.034724 -1.390267  0.792275  0.473031 -0.270488 -0.847963 -1.804085
# ...        ...       ...       ...       ...       ...       ...       ...
# 1448  3.499105  1.069999  0.148971 -0.195977  0.787923  1.016536 -1.977414
# 1449 -1.568786  0.899328  1.192503 -0.286497  2.234500  1.258306 -1.764159
# 1450 -0.414275  1.810438 -1.071948 -0.901031 -0.750299  0.065975  0.720962
# 1451 -2.803630  0.562759  2.278887  0.083924  0.080147 -0.969368 -0.384558
# 1452  3.499105  1.069999  0.148971 -0.195977  0.787923  1.016536 -1.977414
#
#              7         8         9
# ...

# %%
pcaform.describe()
# Out:
#                   0             1             2             3             4  \
# count  1.453000e+03  1.453000e+03  1.453000e+03  1.453000e+03  1.453000e+03
# mean  -2.053874e-16  6.357230e-17 -4.890177e-18 -6.234976e-17  4.645668e-17
# std    1.677250e+00  1.277868e+00  1.175207e+00  1.040053e+00  9.586196e-01
# min   -2.883694e+00 -2.229399e+00 -1.852180e+00 -1.481192e+00 -2.808926e+00
# 25%   -1.082756e+00 -8.196100e-01 -8.166025e-01 -7.415504e-01 -6.594894e-01
# 50%   -2.275531e-01 -4.300592e-02 -1.739581e-01 -1.634068e-01 -2.368836e-02
# 75%    1.079822e+00  9.227436e-01  6.062742e-01  1.380806e-01  4.441573e-01
# max    4.566454e+00  4.102422e+00  4.199369e+00  4.202991e+00  3.606405e+00
#
#                   5             6             7             8             9
# count  1.453000e+03  1.453000e+03  1.453000e+03  1.453000e+03  1.453000e+03
# mean   5.226377e-17  1.100290e-17 -6.723994e-17  3.728760e-17  4.095523e-17
# ...

# %%
pcaform.corr()
# Out:
#               0             1             2             3             4  \
# 0  1.000000e+00 -6.868085e-16  1.469406e-16 -7.929190e-17 -2.655492e-16
# 1 -6.868085e-16  1.000000e+00  8.294006e-17  3.448695e-16  3.943581e-16
# 2  1.469406e-16  8.294006e-17  1.000000e+00 -6.965491e-17 -2.611245e-16
# 3 -7.929190e-17  3.448695e-16 -6.965491e-17  1.000000e+00 -4.361581e-16
# 4 -2.655492e-16  3.943581e-16 -2.611245e-16 -4.361581e-16  1.000000e+00
# 5  2.263367e-16  2.412046e-16  7.045985e-17  4.342727e-16 -1.226261e-16
# 6 -2.962363e-16  2.266708e-16  4.885592e-16  3.985409e-17 -2.259591e-16
# 7 -6.720849e-18 -1.651188e-16 -2.278317e-16  3.474354e-16  1.123205e-16
# 8  3.105214e-16 -9.767818e-17 -2.600013e-16 -5.137609e-17  9.341481e-17
# 9 -6.950170e-16  1.159909e-16 -2.103854e-16  5.124563e-17 -4.064868e-16
#
#               5             6             7             8             9
# 0  2.263367e-16 -2.962363e-16 -6.720849e-18  3.105214e-16 -6.950170e-16
# ...

# %% [markdown]
# ## EDA

# %%
plt.figure(figsize=(10,8))
sns.heatmap(pcaform.describe(),annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(pcaform)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.boxplot(pcaform)
# Out:
# <Axes: >

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=10,init="k-means++")

# %%
y_labels=kmeans.fit_predict(pcaform)

# %%
y_labels
# Out:
# array([1, 6, 0, ..., 7, 3, 9])
